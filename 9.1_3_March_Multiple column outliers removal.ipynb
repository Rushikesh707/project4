# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("Desktop\Project\spotify.csv")
df
# Out:
#         Unnamed: 0                track_id                 artists  \
# 0                0  5SuOikwiRyPMVoIQDJUgSV             Gen Hoshino
# 1                1  4qPNDBW1i3p13qLCt0Ki3A            Ben Woodward
# 2                2  1iJBSr7s7jYXzM8EGcbK5b  Ingrid Michaelson;ZAYN
# 3                3  6lfxq3CG4xtTiEg7opyCyx            Kina Grannis
# 4                4  5vjLSffimiIP26QG5WcN2K        Chord Overstreet
# ...            ...                     ...                     ...
# 113995      113995  2C3TZjDRiAzdyViavDJ217           Rainy Lullaby
# 113996      113996  1hIz5L4IB9hN3WRYPOCGPw           Rainy Lullaby
# 113997      113997  6x8ZfSoqDjuNa5SVP5QjvX           Cesária Evora
# 113998      113998  2e6sXL2bYv4bSz6VTdnfLs        Michael W. Smith
# 113999      113999  2hETkH7cOfqmz3LqZDHZf5           Cesária Evora
#
#                                                album_name  \
# 0                                                  Comedy
# ...

# %%
music.shape
# Out:
# (114000, 21)

# %%
music.describe()
# Out:
#           Unnamed: 0     popularity   duration_ms   danceability  \
# count  114000.000000  114000.000000  1.140000e+05  114000.000000
# mean    56999.500000      33.238535  2.280292e+05       0.566800
# std     32909.109681      22.305078  1.072977e+05       0.173542
# min         0.000000       0.000000  0.000000e+00       0.000000
# 25%     28499.750000      17.000000  1.740660e+05       0.456000
# 50%     56999.500000      35.000000  2.129060e+05       0.580000
# 75%     85499.250000      50.000000  2.615060e+05       0.695000
# max    113999.000000     100.000000  5.237295e+06       0.985000
#
#               energy            key       loudness           mode  \
# count  114000.000000  114000.000000  114000.000000  114000.000000
# mean        0.641383       5.309140      -8.258960       0.637553
# std         0.251529       3.559987       5.029337       0.480709
# min         0.000000       0.000000     -49.531000       0.000000
# ...

# %%
def plot_boxplot(music, ft):
    df.boxplot(column=[ft])
    plt.grid(False)
    plt.show()

# %%
plot_boxplot(df, "popularity")

# %%
plot_boxplot(df, "key")

# %%
plot_boxplot(df, "danceability")

# %%
plot_boxplot(df, "loudness")

# %%
plot_boxplot(df, "acousticness")

# %%
plot_boxplot(df, "instrumentalness")

# %%
plot_boxplot(df, "tempo")

# %%
plot_boxplot(df, "time_signature")

# %%
#Outliers
## time_signature

# %%
q1 = music['time_signature'].quantile(0.25)
q3 = music['time_signature'].quantile(0.75)

# %%
iqr = q3 - q1

# %%
upper_limit = q3 + 1.5 * iqr
lower_limit = q1 - 1.5 * iqr

# %%
music[music['time_signature'] > upper_limit]
music[music['time_signature'] < lower_limit]
# Out:
#         Unnamed: 0                track_id  \
# 3                3  6lfxq3CG4xtTiEg7opyCyx
# 6                6  6Vc5wAMmXdKIAM7WUoEb7N
# 11              11  5ivF4eQBqJiVL5IAE9jRyl
# 15              15  1KHdq8NK9QxnGjdXb55NiG
# 22              22  5TvE3pk05pyFIGdSY9j4DJ
# ...            ...                     ...
# 113964      113964  2SxRPSQg90BMbSIMtCDVc4
# 113965      113965  4DrOtvGcJRQ71S0TPwGMHW
# 113990      113990  2A4dSiJmbviL56CBupkh6C
# 113993      113993  4OkMK49i3NApR1KsAIsTf6
# 113994      113994  4WbOUe6T0sozC7z5ZJgiAA
#
#                                      artists  \
# 3                               Kina Grannis
# 6       A Great Big World;Christina Aguilera
# 11                                Jason Mraz
# 15                               Landon Pigg
# 22      A Great Big World;Christina Aguilera
# ...                                      ...
# 113964                           Matt Redman
# 113965                          Paz Interior
# ...

# %%
time_signature = music[music['time_signature'] < upper_limit]
time_signature.shape
# Out:
# (10331, 21)

# %%
plt.figure(figsize=(16,8))
plt.subplot(2,2,1)
sns.distplot(music['time_signature'])
plt.subplot(2,2,2)
sns.boxplot(music['time_signature'])
plt.subplot(2,2,3)
sns.distplot(new_music['time_signature'])
plt.subplot(2,2,4)
sns.boxplot(new_music['time_signature'])
plt.show()
# Out:
# D:\software\Anaconda\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# D:\software\Anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# D:\software\Anaconda\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
# ...

# %%
# Capping
new_music= music.copy()
new_music['time_signature'] = np.where(new_music['time_signature'] > upper_limit, upper_limit,
    np.where(new_music['time_signature'] < lower_limit, lower_limit, new_music['time_signature']))

# %%
new_music['time_signature'].count()
# Out:
# 114000

# %%
new_music['time_signature'].skew()
# Out:
# -4.098316671758467

# %%
new_music = music.copy()
new_music['duration_ms'] = np.where(new_music['duration_ms'] > upper_limit, upper_limit,
    np.where(new_music['duration_ms'] < lower_limit, lower_limit, new_music['duration_ms']))

# %%
plt.figure(figsize=(16,8))
plt.subplot(2,2,1)
sns.distplot(music['time_signature'])
plt.subplot(2,2,2)
sns.boxplot(music['time_signature'])
plt.subplot(2,2,3)
sns.distplot(new_music['time_signature'])
plt.subplot(2,2,4)
sns.boxplot(new_music['time_signature'])
plt.show()
# Out:
# D:\software\Anaconda\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# D:\software\Anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# D:\software\Anaconda\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
# ...

# %%
#Outliers
## tempo

# %%
q1 = music['tempo'].quantile(0.25)
q3 = music['tempo'].quantile(0.75)

# %%
iqr = q3 - q1

# %%
upper_limit = q3 + 1.5 * iqr
lower_limit = q1 - 1.5 * iqr

# %%
music[music['time_signature'] > upper_limit]
music[music['time_signature'] < lower_limit]
# Out:
#         Unnamed: 0                track_id                 artists  \
# 0                0  5SuOikwiRyPMVoIQDJUgSV             Gen Hoshino
# 1                1  4qPNDBW1i3p13qLCt0Ki3A            Ben Woodward
# 2                2  1iJBSr7s7jYXzM8EGcbK5b  Ingrid Michaelson;ZAYN
# 3                3  6lfxq3CG4xtTiEg7opyCyx            Kina Grannis
# 4                4  5vjLSffimiIP26QG5WcN2K        Chord Overstreet
# ...            ...                     ...                     ...
# 113995      113995  2C3TZjDRiAzdyViavDJ217           Rainy Lullaby
# 113996      113996  1hIz5L4IB9hN3WRYPOCGPw           Rainy Lullaby
# 113997      113997  6x8ZfSoqDjuNa5SVP5QjvX           Cesária Evora
# 113998      113998  2e6sXL2bYv4bSz6VTdnfLs        Michael W. Smith
# 113999      113999  2hETkH7cOfqmz3LqZDHZf5           Cesária Evora
#
#                                                album_name  \
# 0                                                  Comedy
# ...

# %%
new_music = music[music['tempo'] < upper_limit]
new_music.shape
# Out:
# (113553, 21)

# %%
plt.figure(figsize=(16,8))
plt.subplot(2,2,1)
sns.distplot(music['tempo'])
plt.subplot(2,2,2)
sns.boxplot(music['tempo'])
plt.subplot(2,2,3)
sns.distplot(new_music['tempo'])
plt.subplot(2,2,4)
sns.boxplot(new_music['tempo'])
plt.show()
# Out:
# D:\software\Anaconda\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# D:\software\Anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# D:\software\Anaconda\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
# ...

# %%
# min max scaling
music['tempo'] = (music['tempo'] - music['tempo'].min()) / (music['tempo'].max() - music['tempo'].min())

# %%
sns.distplot(music['tempo'])
# Out:
# D:\software\Anaconda\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='tempo', ylabel='Density'>
