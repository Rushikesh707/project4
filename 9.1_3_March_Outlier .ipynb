# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
music = pd.read_csv("Desktop\Project\spotify.csv")
music
# Out:
#         Unnamed: 0                track_id                 artists  \
# 0                0  5SuOikwiRyPMVoIQDJUgSV             Gen Hoshino
# 1                1  4qPNDBW1i3p13qLCt0Ki3A            Ben Woodward
# 2                2  1iJBSr7s7jYXzM8EGcbK5b  Ingrid Michaelson;ZAYN
# 3                3  6lfxq3CG4xtTiEg7opyCyx            Kina Grannis
# 4                4  5vjLSffimiIP26QG5WcN2K        Chord Overstreet
# ...            ...                     ...                     ...
# 113995      113995  2C3TZjDRiAzdyViavDJ217           Rainy Lullaby
# 113996      113996  1hIz5L4IB9hN3WRYPOCGPw           Rainy Lullaby
# 113997      113997  6x8ZfSoqDjuNa5SVP5QjvX           Cesária Evora
# 113998      113998  2e6sXL2bYv4bSz6VTdnfLs        Michael W. Smith
# 113999      113999  2hETkH7cOfqmz3LqZDHZf5           Cesária Evora
#
#                                                album_name  \
# 0                                                  Comedy
# ...

# %%
plt.figure(figsize=(16,5))
plt.subplot(1,2,1)
sns.distplot(music['popularity'])
plt.subplot(1,2,2)
sns.distplot(music['duration_ms'])
plt.show()
# Out:
# D:\software\Anaconda\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# D:\software\Anaconda\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.boxplot(music['duration_ms'])
# Out:
# D:\software\Anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='duration_ms'>

# %%
q1 = music['duration_ms'].quantile(0.25)
q3 = music['duration_ms'].quantile(0.75)

# %%
iqr = q3 - q1

# %%
upper_limit = q3 + 1.5 * iqr
lower_limit = q1 - 1.5 * iqr

# %%
music['duration_ms'].count()
# Out:
# 114000

# %%
a = music[music['duration_ms'] > upper_limit]
a
# Out:
#         Unnamed: 0                track_id                 artists  \
# 0                0  5SuOikwiRyPMVoIQDJUgSV             Gen Hoshino
# 1                1  4qPNDBW1i3p13qLCt0Ki3A            Ben Woodward
# 2                2  1iJBSr7s7jYXzM8EGcbK5b  Ingrid Michaelson;ZAYN
# 3                3  6lfxq3CG4xtTiEg7opyCyx            Kina Grannis
# 4                4  5vjLSffimiIP26QG5WcN2K        Chord Overstreet
# ...            ...                     ...                     ...
# 113995      113995  2C3TZjDRiAzdyViavDJ217           Rainy Lullaby
# 113996      113996  1hIz5L4IB9hN3WRYPOCGPw           Rainy Lullaby
# 113997      113997  6x8ZfSoqDjuNa5SVP5QjvX           Cesária Evora
# 113998      113998  2e6sXL2bYv4bSz6VTdnfLs        Michael W. Smith
# 113999      113999  2hETkH7cOfqmz3LqZDHZf5           Cesária Evora
#
#                                                album_name  \
# 0                                                  Comedy
# ...

# %%
b = music[music['duration_ms'] < lower_limit]
b
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, track_id, artists, album_name, track_name, popularity, duration_ms, explicit, danceability, energy, key, loudness, mode, speechiness, acousticness, instrumentalness, liveness, valence, tempo, time_signature, track_genre]
# Index: []
#
# [0 rows x 21 columns]

# %%
c = a+b
c
# Out:
#         Unnamed: 0 track_id artists album_name track_name  popularity  \
# 0              NaN      NaN     NaN        NaN        NaN         NaN
# 1              NaN      NaN     NaN        NaN        NaN         NaN
# 2              NaN      NaN     NaN        NaN        NaN         NaN
# 3              NaN      NaN     NaN        NaN        NaN         NaN
# 4              NaN      NaN     NaN        NaN        NaN         NaN
# ...            ...      ...     ...        ...        ...         ...
# 113995         NaN      NaN     NaN        NaN        NaN         NaN
# 113996         NaN      NaN     NaN        NaN        NaN         NaN
# 113997         NaN      NaN     NaN        NaN        NaN         NaN
# 113998         NaN      NaN     NaN        NaN        NaN         NaN
# 113999         NaN      NaN     NaN        NaN        NaN         NaN
#
#         duration_ms explicit  danceability  energy  ...  loudness  mode  \
# ...

# %%
#Trimming

# %%
new_df = music[music['duration_ms'] < upper_limit]
new_df.shape
# Out:
# (108656, 21)

# %%
plt.figure(figsize=(16,8))
plt.subplot(2,2,1)
sns.distplot(music['duration_ms'])
plt.subplot(2,2,2)
sns.boxplot(music['duration_ms'])
plt.subplot(2,2,3)
sns.distplot(new_df['duration_ms'])
plt.subplot(2,2,4)
sns.boxplot(new_df['duration_ms'])
plt.show()
# Out:
# D:\software\Anaconda\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# D:\software\Anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# D:\software\Anaconda\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
# ...

# %%
# Capping

# %%
new_df_cap = music.copy()
new_df_cap['duration_ms'] = np.where(new_df_cap['duration_ms'] > upper_limit, upper_limit,
    np.where(new_df_cap['duration_ms'] < lower_limit, lower_limit, new_df_cap['duration_ms']))

# %%
plt.figure(figsize=(16,8))
plt.subplot(2,2,1)
sns.distplot(music['duration_ms'])
plt.subplot(2,2,2)
sns.boxplot(music['duration_ms'])
plt.subplot(2,2,3)
sns.distplot(new_df_cap['duration_ms'])
plt.subplot(2,2,4)
sns.boxplot(new_df_cap['duration_ms'])
plt.show()
# Out:
# D:\software\Anaconda\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# D:\software\Anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# D:\software\Anaconda\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
# ...

# %%
new_df.skew()
# Out:
# C:\Users\Akshay.LAPTOP-28VV15LR\AppData\Local\Temp\ipykernel_11568\3313494185.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   new_df.skew()
# Unnamed: 0         -0.015801
# popularity          0.033563
# duration_ms         0.241905
# explicit            2.911046
# danceability       -0.390822
# energy             -0.594472
# key                -0.008455
# loudness           -2.048942
# mode               -0.582474
# speechiness         4.572384
# acousticness        0.711132
# instrumentalness    1.902757
# liveness            2.119211
# valence             0.095241
# tempo               0.244662
# time_signature     -4.102948
# dtype: float64

# %%
q1 = music['speechiness'].quantile(0.25)
q3 = music['speechiness'].quantile(0.75)

# %%
iqr = q3 - q1

# %%
upper_limit = q3 + 1.5 * iqr
lower_limit = q1 - 1.5 * iqr

# %%
music[music['speechiness'] > upper_limit]
# Out:
#         Unnamed: 0                track_id                        artists  \
# 370            370  1wSZdWFZphxDh6iJhWlIUi                   Ben Woodward
# 692            692  5CU7ewecONNlWAJHu04HJQ        The Bridge City Sinners
# 713            713  1z2fSrYZqrO5tMqzULn9OD                   Tyrone Wells
# 768            768  1m3Lsbhkn6yL8apzsCiukd                   Ben Woodward
# 815            815  10a6GUpyRLdfadUPRL5wBg  Postcards & Polaroids;Sad Boy
# ...            ...                     ...                            ...
# 113549      113549  60iVN2c4KpoB9teVSBzmzt     Reiki Armonía;Paz Interior
# 113818      113818  7iBIuW0do6NaHXQ7Jueu67             for KING & COUNTRY
# 113923      113923  4wl9wFhVgT4ucd72OEpEeZ  for KING & COUNTRY;Dante Bowe
# 113940      113940  3Fj6wu6AAnltIyS2jNbqiG                   Flor de Loto
# 113981      113981  1pBc7W7UQacUeQ6kBVlN9f                  Planetshakers
#
#                                                album_name  \
# ...

# %%
music[music['speechiness'] < lower_limit]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, track_id, artists, album_name, track_name, popularity, duration_ms, explicit, danceability, energy, key, loudness, mode, speechiness, acousticness, instrumentalness, liveness, valence, tempo, time_signature, track_genre]
# Index: []
#
# [0 rows x 21 columns]

# %%
speechiness_1 = music[music['speechiness'] < upper_limit]
speechiness_1.shape
# Out:
# (100789, 21)

# %%
plt.figure(figsize=(16,8))
plt.subplot(2,2,1)
sns.distplot(music['speechiness'])
plt.subplot(2,2,2)
sns.boxplot(music['speechiness'])
plt.subplot(2,2,3)
sns.distplot(speechiness_1['speechiness'])
plt.subplot(2,2,4)
sns.boxplot(speechiness_1['speechiness'])
plt.show()
# Out:
# D:\software\Anaconda\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# D:\software\Anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# D:\software\Anaconda\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
# ...

# %%
speechiness_1.skew()
# Out:
# C:\Users\Akshay.LAPTOP-28VV15LR\AppData\Local\Temp\ipykernel_11568\517167318.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   speechiness_1.skew()
# Unnamed: 0          -0.035676
# popularity           0.021175
# duration_ms         11.767523
# explicit             3.701166
# danceability        -0.407930
# energy              -0.568495
# key                 -0.001680
# loudness            -2.005571
# mode                -0.613929
# speechiness          1.506568
# acousticness         0.705633
# instrumentalness     1.634179
# liveness             2.195619
# valence              0.144124
# tempo                0.206259
# time_signature      -4.316268
# dtype: float64

# %%
q1 = music['instrumentalness'].quantile(0.25)
q3 = music['instrumentalness'].quantile(0.75)

# %%
iqr = q3 - q1

# %%
upper_limit = q3 + 1.5 * iqr
lower_limit = q1 - 1.5 * iqr

# %%
music[music['instrumentalness'] > upper_limit]
music[music['instrumentalness'] < lower_limit]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, track_id, artists, album_name, track_name, popularity, duration_ms, explicit, danceability, energy, key, loudness, mode, speechiness, acousticness, instrumentalness, liveness, valence, tempo, time_signature, track_genre]
# Index: []
#
# [0 rows x 21 columns]

# %%
instru_1 = music[music['instrumentalness'] < upper_limit]
instru_1.shape
# Out:
# (88754, 21)

# %%
plt.figure(figsize=(16,8))
plt.subplot(2,2,1)
sns.distplot(music['instrumentalness'])
plt.subplot(2,2,2)
sns.boxplot(music['instrumentalness'])
plt.subplot(2,2,3)
sns.distplot(instru_1['instrumentalness'])
plt.subplot(2,2,4)
sns.boxplot(instru_1['instrumentalness'])
plt.show()
# Out:
# D:\software\Anaconda\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# D:\software\Anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# D:\software\Anaconda\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
# ...

# %%
instru_1.skew()
# Out:
# C:\Users\Akshay.LAPTOP-28VV15LR\AppData\Local\Temp\ipykernel_11568\3872817008.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   instru_1.skew()
# Unnamed: 0         -0.089533
# popularity         -0.024341
# duration_ms         8.399250
# explicit            2.660549
# danceability       -0.225651
# energy             -0.547495
# key                -0.013817
# loudness           -1.433717
# mode               -0.638549
# speechiness         4.377712
# acousticness        0.723281
# instrumentalness    4.467178
# liveness            2.031813
# valence             0.033061
# tempo               0.338927
# time_signature     -4.032496
# dtype: float64

# %%
q1 = music['time_signature'].quantile(0.25)
q3 = music['time_signature'].quantile(0.75)

# %%
iqr = q3 - q1

# %%
upper_limit = q3 + 1.5 * iqr
lower_limit = q1 - 1.5 * iqr

# %%
music[music['time_signature'] > upper_limit]
music[music['time_signature'] < lower_limit]
# Out:
#         Unnamed: 0                track_id  \
# 3                3  6lfxq3CG4xtTiEg7opyCyx
# 6                6  6Vc5wAMmXdKIAM7WUoEb7N
# 11              11  5ivF4eQBqJiVL5IAE9jRyl
# 15              15  1KHdq8NK9QxnGjdXb55NiG
# 22              22  5TvE3pk05pyFIGdSY9j4DJ
# ...            ...                     ...
# 113964      113964  2SxRPSQg90BMbSIMtCDVc4
# 113965      113965  4DrOtvGcJRQ71S0TPwGMHW
# 113990      113990  2A4dSiJmbviL56CBupkh6C
# 113993      113993  4OkMK49i3NApR1KsAIsTf6
# 113994      113994  4WbOUe6T0sozC7z5ZJgiAA
#
#                                      artists  \
# 3                               Kina Grannis
# 6       A Great Big World;Christina Aguilera
# 11                                Jason Mraz
# 15                               Landon Pigg
# 22      A Great Big World;Christina Aguilera
# ...                                      ...
# 113964                           Matt Redman
# 113965                          Paz Interior
# ...

# %%
time_signature = music[music['time_signature'] < upper_limit]
time_signature.shape
# Out:
# (10331, 21)

# %%
plt.figure(figsize=(16,8))
plt.subplot(2,2,1)
sns.distplot(new_music['time_signature'])
plt.subplot(2,2,2)
sns.boxplot(new_music['time_signature'])
plt.subplot(2,2,3)
sns.distplot(time_signature['time_signature'])
plt.subplot(2,2,4)
sns.boxplot(time_signature['time_signature'])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11568\4094371205.py in <module>
#       1 plt.figure(figsize=(16,8))
#       2 plt.subplot(2,2,1)
# ----> 3 sns.distplot(new_music['time_signature'])
#       4 plt.subplot(2,2,2)
#       5 sns.boxplot(new_music['time_signature'])
#
# NameError: name 'new_music' is not defined
